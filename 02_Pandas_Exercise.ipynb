# %% [markdown]
# # Pandas Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
#
# **Import pandas and read in the 'data/Ecommerce Purchases.csv' file and set it to a DataFrame called ecom.**

# %%
import pandas as pd

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
df.head()

# %% [markdown]
# **How many rows and columns are there?**

# %%
df.shape

# %% [markdown]
# **What is the average Purchase Price?**

# %%
df['Purchase Price'].mean()

# %% [markdown]
# **What were the highest and lowest purchase prices?**

# %%
df['Purchase Price'].max()
df['Purchase Price'].min()

# %% [markdown]
# **How many people have English 'en' as their Language of choice on the website?**

# %%
df['Language'].value_counts()['en']

# %% [markdown]
# **How many people have the job title of "Lawyer" ?**

# %%
df['Job'].value_counts()['Lawyer']

# %% [markdown]
# **How many people made the purchase during the AM and how many people made the purchase during PM ?**
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) )**

# %%
am_count = df['AM or PM'].value_counts()['AM']
pm_count = df['AM or PM'].value_counts()['PM']

print("Purchases during AM:", am_count)
print("Purchases during PM:", pm_count)

# %% [markdown]
# **What are the 5 most common Job Titles?**

# %%
df['Job'].value_counts().head(5)

# %% [markdown]
# **Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction?**

# %%
df[df['Lot'] == '90 WT']['Purchase Price']

# %% [markdown]
# **What is the email of the person with the following Credit Card Number: 4926535242672853**

# %% [markdown]
# **How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
len(df[(df['Credit Card Provider'] == 'American Express') & (df['Purchase Price'] > 95)])

# %% [markdown]
# **Hard: How many people have a credit card that expires in 2025?**

# %%
df['Credit Card Exp Date'] = pd.to_datetime(df['Credit Card Exp Date'])
len(df[df['Credit Card Exp Date'].dt.year == 2025])

# %% [markdown]
# **Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...)**

# %%
df['Email Domain'] = df['Email'].str.split('@').str[1]
top_5_domains = df['Email Domain'].value_counts().head(5)

print(top_5_domains)

# %% [markdown]
# # Great Job!
